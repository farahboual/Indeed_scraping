8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.9/12.9 MB 4.8 MB/s eta 0:00:02
#    --------------- ------------------------ 5.1/12.9 MB 4.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.3/12.9 MB 4.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.6/12.9 MB 4.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.8/12.9 MB 4.8 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/12.9 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 6.2/12.9 MB 4.9 MB/s eta 0:00:02
#    -------------------- ------------------- 6.5/12.9 MB 4.9 MB/s eta 0:00:02
#    -------------------- ------------------- 6.7/12.9 MB 4.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.9/12.9 MB 4.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.9 MB 4.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.4/12.9 MB 4.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.6/12.9 MB 4.8 MB/s eta 0:00:02
#    ------------------------ --------------- 7.8/12.9 MB 4.8 MB/s eta 0:00:02
#    ------------------------ --------------- 8.0/12.9 MB 4.8 MB/s eta 0:00:02
#    ------------------------- -------------- 8.3/12.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.5/12.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/12.9 MB 4.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.9 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.9 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.6/12.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 9.8/12.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 10.1/12.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 10.3/12.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 4.9 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 10.9/12.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.2/12.9 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.4/12.9 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.6/12.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 12.3/12.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 12.5/12.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  12.7/12.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 4.7 MB/s eta 0:00:00
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.2 pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from database_tools import DatabaseTools
db = DatabaseTools()

# Select all the tables in the database
db.list_tables()
# Out:
# Listing tables in database: c:\Users\DELL\Desktop\indeed_job_scraper-main\indeed.db
# ['search_sessions', 'job_postings', 'job_details']

# %%
# Select the records that were collected today
df = db.sql_to_df("select * from job_postings where date(timestamp) = date('now')")
df
# Out:
# Empty DataFrame
# Columns: [id, session_id, job_unique_id, job_title, job_link, job_description, timestamp]
# Index: []

# %%
# View a single job description
print(df.loc[0].job_description)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 # View a single job description
# ----> 2 print(df.loc[0].job_description)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 0

# %%
# Print the job description with the links removed, if you're trying to save on tokens (for ai stuff)
from indeed_scraper import IndeedScraper
scraper = IndeedScraper()
print(scraper.remove_links_from_markdown(df.loc[0].job_description))
# Out:
# Indeed Scraper Initialized
# Data Analyst I==============[Mullen Coughlin LLC](<url removed>)3.2 out of 5RemoteFull-time[Mullen Coughlin LLC-------------------5 reviewsRead what people are saying about working here.](<url removed>)Profile insights----------------Find out how your skills align with the job description### SkillsDo you have experience in **SQL**?YesNo### EducationDo you have a **Bachelor's degree**?YesNo&nbsp;Job details-----------Here’s how the job details align with your [profile](<url removed>).### Job type* Full-time&nbsp;Location--------Remote&nbsp;BenefitsPulled from the full job description--------------------------------------------* 401(k)* Work from home&nbsp;Full job description-------------------- Data Analyst I  Mullen Coughlin is a highly successful, fast growing niche law firm focused exclusively on counseling organizations in the context of data privacy, including incident response, regulatory investigation, single-plaintiff and class action litigation compliance. Committed to rapid incident response to incoming client calls, we thrive in a high energy, close-knit, and upbeat office culture. The Firm pays very competitively in the market and offers a full benefit package, including accrued time off and a generous 401(k) program. At its new location, 426 West Lancaster Avenue, Devon, PA, Mullen Coughlin’s home office is over fifty-six thousand square feet, boasting the latest in technology and security, accommodating the projected continued growth of the firm, and providing all Mullen Coughlin employees access to amenities and resources to further their professional careers, as well as their health and well-being.  We are looking for a new Data Analyst I to join our team! The ideal candidate will demonstrate creative, technical, and interpersonal skills, and the ability to work closely with other members of the team. This is a full-time, non-exempt position with the option to work remotely. **Sample of Essential Responsibilities*** Efficiently interpret and organize sensitive data sets to support legal matters related to data privacy cases.* Develop applicable data analytics and processing tools/systems to enable expedited processing of data sets.* Use different coding methods to clean, manipulate, and transform data received from various sources.* Perform initial analysis to assess quality of data.* Identify, analyze, and interpret trends or patterns in complex data sets.* Work with Data Engineer(s), CIO, and designated Attorneys to prioritize business and information needs.* Work effectively with teammates in a fast-paced environment meeting hard deadlines and potentially short turnaround times.* Provide timely status reports and updates to management or attorneys about various duties and assignments.* Communicate data analytic insights to various internal and external clients when applicable.* Design and create scalable solutions for data management and other process improvements.* Support the firm with other database/analytics projects as directed.**Desired Skills, Qualifications, and Experience*** Must have highest integrity and the ability to treat confidential information appropriately.* 1+ years’ experience working with data management or as a data analyst.* BS in Computer Science or related field, *a plus but not required*.* Advanced Excel skills and experience writing excel functions to manipulate/enrich data (i.e. if-then statements, vlookups, text-join, left, mid, right, etc.)* 1+ year programming experience in Python, *preferred*.* Experience with SQL, MySQL, and/or PostgreSQL.* Experience using source control, *a plus* (Git).* Data analytics, big data, and/or other IT certifications, *a plus*.* A resourceful problem-solver who seeks out effective and efficient solutions.* Excellent interpersonal and verbal/written communications skills; adaptability; and situational sensitivity.* Candidate should be comfortable balancing multiple assignments/cases.* Demonstrated process improvement experience, resourcefulness, an ...
